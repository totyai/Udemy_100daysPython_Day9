# %% [markdown]
# # Day 9
# Dictionaries, Nesting

# %% [markdown]
# ## Dictionaries
# Group and pair related infomraiton. It has the Key-value pair. Key would be the some that is serach for and the value is the definition.
# Sytax:
# {"Key": "Value"}
# {"Bug":"An error."}
#
# If there are more items, you can separate them via a ,
# If there is more then 1 item, it is good practice to separate them wtih each line

# %%
programing_dictionary = {"Bug": "An error in the code", "Function": "A piece of code that you can call."}
programing_dictionary2 = {
    "Bug": "An error",
    "Function": "A piece of code block",
}
print(programing_dictionary, programing_dictionary2)
# Out:
# {'Bug': 'An error in the code', 'Function': 'A piece of code that you can call.'} {'Bug': 'An error', 'Function': 'A piece of code block'}

# %% [markdown]
# Retriveing an item from the list, is by using the Key with [], but it is important ot have the key from the dictionary correctly syntaxed.
# Make sure that the data type for the key are correct. It does'n necessery be string, but usually it is.

# %%
print(programing_dictionary["Bug"])
# Out:
# An error in the code

# %% [markdown]
# Adding new item to an already existing dict is by the following:

# %%
programing_dictionary["Loop"] = "Is a built in function of python"
print(programing_dictionary)
# Out:
# {'Bug': 'An error in the code', 'Function': 'A piece of code that you can call.', 'Loop': 'Is a built in function of python'}

# %% [markdown]
# If you want to delete the values in an already exiting dictonary (basically declare it once again):

# %%
programing_dictionary = {}

# %% [markdown]
# To redifine the vlaue of an already exisitng item, you call it and assign new value

# %%
programing_dictionary2["Bug"] = "New definition"
print(programing_dictionary2)
# Out:
# {'Bug': 'New definition', 'Function': 'A piece of code block'}

# %% [markdown]
# Looping through a dictonary to get back the values, has a trick in.
# If you loop through the dict, you will get back the list of keys.
# And if you want the corresponding values, then call these keys

# %%
for item in programing_dictionary2:
    print(item) # key
    print(programing_dictionary2[item]) # Each value
# Out:
# Bug
# New definition
# Function
# A piece of code block

# %% [markdown]
# ### Coding excercise
# **Grading Program**
# You have access to a database of `student_scores` in the format of a dictionary. The keys in `student_scores` are the names of the students and the values are their exam scores.
#
# Write a program that converts their scores to grades.
#
# By the end of your program, you should have a new dictionary called `student_grades` that should contain student names as keys and their assessed grades for values.
#
# The final version of the `student_grades` dictionary will be checked.
#
# **DO NOT** modify lines 1-7 to change the existing student_scores dictionary.
#
# This is the scoring criteria:
# - Scores 91 - 100: Grade = "Outstanding"
# - Scores 81 - 90: Grade = "Exceeds Expectations"
# - Scores 71 - 80: Grade = "Acceptable"
# - Scores 70 or lower: Grade = "Fail"
#
# **Note:** With the student_score.key() - you can retrive back a list of keys from the dict

# %%
student_scores = {
    'Harry': 88,
    'Ron': 78,
    'Hermione': 95,
    'Draco': 75,
    'Neville': 60
}

student_grades = {}

for student in student_scores.keys():
    if student_scores[student] < 71:
        student_grades[student] = "Fail"
    elif student_scores[student] > 70 and student_scores[student] < 81:
        student_grades[student] = "Acceptable"
    elif student_scores[student] > 80 and student_scores[student] < 91:
        student_grades[student] = "Exceeds Expectations"
    else:
        student_grades[student] = "Outstanding"
 
print(student_grades)
# Out:
# {'Harry': 'Exceeds Expectations', 'Ron': 'Acceptable', 'Hermione': 'Outstanding', 'Draco': 'Acceptable', 'Neville': 'Fail'}

# %% [markdown]
# ## Nesting
# Basically it puts something instide an other. Therefore we can mix and match the dict and list as well. So we can use it inside each other:
# My_dict = {"Key": [List], "Key": {"Dict2_key": "Dict2_Value}}

# %%
capital = {
    "France": "Paris",
    "Germany": "Berlin" 
}

travel_log = {
    "France": ["Paris", "Lille", "Dijon"],
    "Germany": ["Stuttgart", "Berlin"] 
}

# Print Lille - here you need to mix the calling of dict and list
print(travel_log["France"][1])

#print the D
nested_list = ["A", "B", ["C", "D"]]
print(nested_list[2][1])

travel_log2 = {
    "France": {
        "num_times_visited": 8,
        "cities_visited": ["Paris", "Lille", "Dijon"]
    },
    "Germany": {
        "cities_visited": ["Hamburg","Stuttgart", "Berlin"],
        "total_visits": 5,
    }
}

#Print out Stuttgart
print(travel_log2["Germany"]["cities_visited"][1])
# Out:
# Lille
# D
# Stuttgart

# %%
import silent_auction
silent_auction
